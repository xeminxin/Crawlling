# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By

import time
import os 
import urllib, requests

# %%
### 1. qurey 선언 / chromedriver 실행
qurey = "고양이"
service = Service("./chromedriver")
driver = webdriver.Chrome(service=service)

###2. query 검색창에 추가 
driver.get("https://www.google.co.kr/imghp?h1=ko")
# keyword = driver.find_element_by_xpath("/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/textarea")
keyword = driver.find_element_by_class_name('gLFyf')
keyword.send_keys(qurey)
# /html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/textarea -> 검색창
# /html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/button -> 검색창 버튼 

### 검색창에 입력어 들어오면 검색 실행 
# driver.find_element_by_xpath("/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/button/div/span/svg").click()
driver.find_element_by_class_name('Tg7LZd').send_keys(Keys.ENTER)

### 스크롤 내려가기 -> 검색 더보기 클릭 후 -> 스크롤 내려가기 
elem = driver.find_element_by_tag_name('body')
for i in range(20) : 
    elem.send_keys(Keys.PAGE_DOWN)
    time.sleep(0.1)
    
try : 
    driver.find_element_by_class_name('mye4qd').send_keys(Keys.ENTER)
    for i in range(20) : 
        elem.send_keys(Keys.PAGE_DOWN)
        time.sleep(0.1)
except :
    pass

images = driver.find_elements(By.CSS_SELECTOR, value=".rg_i.Q4LuWd")

### 이미지 다운로드 
count = 0
for i in images : 
    start = time.time()
    
    os.makedirs("./cat02", exist_ok=True)
    try :
        i.click()
        # 2초로 설정한 이유는 IP 차단 당하지 않기 위함 !  
        time.sleep(2)

        # 개발자 모드에서 돋보기 이용해서 해당 이미지의 코드로 이동하게 된다. 
        # 그 코드에 대고 마우스 오른쪽 버튼을 눌러 copy -> xpath를 눌러주면 쉽게 복사할 수 있다. 복사된 xpath를 find_element_by_xpath() 안에 넣어주면 된다.
        # 원본이미지 저장됩니다.
        imgUrl = driver.find_element(By.XPATH,'//*[@id="Sva75c"]/div[2]/div/div[2]/div[2]/div[2]/c-wiz/div/div/div/div[3]/div[1]/a/img[1]').get_attribute("src")
        urllib.request.urlretrieve(imgUrl, f"./cat02/{str(count)}_cat.png")
        print(f" {qurey} >>> 다운로드 시간 : {str(time.time() - start)[:5]} 초")
        count = count + 1 

    except :
        pass
    
print("다운로드 완료")
driver.close()
# Out:
# C:\Users\smjin\AppData\Local\Temp\ipykernel_7376\169236170.py:9: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   keyword = driver.find_element_by_class_name('gLFyf')
# C:\Users\smjin\AppData\Local\Temp\ipykernel_7376\169236170.py:16: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   driver.find_element_by_class_name('Tg7LZd').send_keys(Keys.ENTER)
# C:\Users\smjin\AppData\Local\Temp\ipykernel_7376\169236170.py:19: DeprecationWarning: find_element_by_tag_name is deprecated. Please use find_element(by=By.TAG_NAME, value=name) instead
#   elem = driver.find_element_by_tag_name('body')
# C:\Users\smjin\AppData\Local\Temp\ipykernel_7376\169236170.py:25: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   driver.find_element_by_class_name('mye4qd').send_keys(Keys.ENTER)
#  고양이 >>> 다운로드 시간 : 2.380 초
#  고양이 >>> 다운로드 시간 : 2.432 초
#  고양이 >>> 다운로드 시간 : 2.391 초
#  고양이 >>> 다운로드 시간 : 3.856 초
#  고양이 >>> 다운로드 시간 : 2.236 초
#  고양이 >>> 다운로드 시간 : 3.210 초
#  고양이 >>> 다운로드 시간 : 2.436 초
#  고양이 >>> 다운로드 시간 : 2.338 초
#  고양이 >>> 다운로드 시간 : 2.325 초
#  고양이 >>> 다운로드 시간 : 2.255 초
#  고양이 >>> 다운로드 시간 : 2.223 초
#  고양이 >>> 다운로드 시간 : 2.587 초
#  고양이 >>> 다운로드 시간 : 2.322 초
#  고양이 >>> 다운로드 시간 : 2.277 초
#  고양이 >>> 다운로드 시간 : 2.863 초
#  고양이 >>> 다운로드 시간 : 2.275 초
#  고양이 >>> 다운로드 시간 : 2.206 초
#  고양이 >>> 다운로드 시간 : 2.289 초
#  고양이 >>> 다운로드 시간 : 2.201 초
#  고양이 >>> 다운로드 시간 : 2.323 초
#  고양이 >>> 다운로드 시간 : 2.220 초
#  고양이 >>> 다운로드 시간 : 2.223 초
#  고양이 >>> 다운로드 시간 : 2.280 초
#  고양이 >>> 다운로드 시간 : 2.188 초
#  고양이 >>> 다운로드 시간 : 2.206 초
#  고양이 >>> 다운로드 시간 : 2.513 초
#  고양이 >>> 다운로드 시간 : 2.176 초
#  고양이 >>> 다운로드 시간 : 2.557 초
#  고양이 >>> 다운로드 시간 : 2.352 초
#  고양이 >>> 다운로드 시간 : 2.352 초
#  고양이 >>> 다운로드 시간 : 2.351 초
#  고양이 >>> 다운로드 시간 : 2.204 초
#  고양이 >>> 다운로드 시간 : 2.283 초
#  고양이 >>> 다운로드 시간 : 2.386 초
#  고양이 >>> 다운로드 시간 : 2.295 초
#  고양이 >>> 다운로드 시간 : 2.368 초
#  고양이 >>> 다운로드 시간 : 2.252 초
#  고양이 >>> 다운로드 시간 : 2.273 초
#  고양이 >>> 다운로드 시간 : 2.222 초
#  고양이 >>> 다운로드 시간 : 3.450 초
#  고양이 >>> 다운로드 시간 : 2.347 초
#  고양이 >>> 다운로드 시간 : 2.184 초
#  고양이 >>> 다운로드 시간 : 2.372 초
#  고양이 >>> 다운로드 시간 : 2.282 초
#  고양이 >>> 다운로드 시간 : 2.844 초
#  고양이 >>> 다운로드 시간 : 2.215 초
#  고양이 >>> 다운로드 시간 : 2.207 초
#  고양이 >>> 다운로드 시간 : 2.498 초
# 다운로드 완료

# %%
import glob
from natsort import natsort
file_list_sort = natsort.natsorted(glob.glob(os.path.join("./cat/", "*.png")))
print(file_list_sort)
# Out:
# ['./cat\\0_cat.png', './cat\\1_cat.png', './cat\\2_cat.png', './cat\\3_cat.png', './cat\\4_cat.png', './cat\\5_cat.png', './cat\\6_cat.png', './cat\\8_cat.png', './cat\\9_cat.png', './cat\\10_cat.png', './cat\\11_cat.png', './cat\\14_cat.png', './cat\\15_cat.png', './cat\\16_cat.png', './cat\\17_cat.png', './cat\\18_cat.png', './cat\\19_cat.png', './cat\\20_cat.png', './cat\\21_cat.png', './cat\\22_cat.png', './cat\\23_cat.png', './cat\\24_cat.png', './cat\\25_cat.png', './cat\\27_cat.png', './cat\\28_cat.png', './cat\\30_cat.png', './cat\\31_cat.png', './cat\\33_cat.png', './cat\\34_cat.png', './cat\\35_cat.png', './cat\\36_cat.png', './cat\\38_cat.png', './cat\\39_cat.png', './cat\\40_cat.png', './cat\\41_cat.png', './cat\\42_cat.png', './cat\\43_cat.png', './cat\\46_cat.png', './cat\\47_cat.png', './cat\\50_cat.png', './cat\\51_cat.png', './cat\\52_cat.png', './cat\\53_cat.png', './cat\\54_cat.png', './cat\\55_cat.png', './cat\\56_cat.png', './cat\\57_cat.png', './cat\\58_cat.png', './cat\\59_cat.png', './cat\\60_cat.png', './cat\\61_cat.png', './cat