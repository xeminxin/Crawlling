# %%
# !pip install selenium==4.2.0
# Out:
# Requirement already satisfied: selenium==4.2.0 in c:\users\smjin\anaconda3\envs\ai\lib\site-packages (4.2.0)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\smjin\anaconda3\envs\ai\lib\site-packages (from selenium==4.2.0) (0.10.3)
# Requirement already satisfied: trio~=0.17 in c:\users\smjin\anaconda3\envs\ai\lib\site-packages (from selenium==4.2.0) (0.22.0)
# Requirement already satisfied: urllib3[secure,socks]~=1.26 in c:\users\smjin\anaconda3\envs\ai\lib\site-packages (from selenium==4.2.0) (1.26.16)
# Requirement already satisfied: sortedcontainers in c:\users\smjin\anaconda3\envs\ai\lib\site-packages (from trio~=0.17->selenium==4.2.0) (2.4.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in c:\users\smjin\anaconda3\envs\ai\lib\site-packages (from trio~=0.17->selenium==4.2.0) (1.1.1)
# Requirement already satisfied: cffi>=1.14 in c:\users\smjin\anaconda3\envs\ai\lib\site-packages (from trio~=0.17->selenium==4.2.0) (1.15.1)
# Requirement already satisfied: outcome in c:\users\smjin\anaconda3\envs\ai\lib\site-packages (from trio~=0.17->selenium==4.2.0) (1.2.0)
# Requirement already satisfied: async-generator>=1.9 in c:\users\smjin\anaconda3\envs\ai\lib\site-packages (from trio~=0.17->selenium==4.2.0) (1.10)
# Requirement already satisfied: idna in c:\users\smjin\anaconda3\envs\ai\lib\site-packages (from trio~=0.17->selenium==4.2.0) (3.4)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\smjin\anaconda3\envs\ai\lib\site-packages (from trio~=0.17->selenium==4.2.0) (23.1.0)
# Requirement already satisfied: sniffio in c:\users\smjin\anaconda3\envs\ai\lib\site-packages (from trio~=0.17->selenium==4.2.0) (1.3.0)
# Requirement already satisfied: wsproto>=0.14 in c:\users\smjin\anaconda3\envs\ai\lib\site-packages (from trio-websocket~=0.9->selenium==4.2.0) (1.2.0)
# Requirement already satisfied: cryptography>=1.3.4 in c:\users\smjin\anaconda3\envs\ai\lib\site-packages (from urllib3[secure,socks]~=1.26->selenium==4.2.0) (39.0.1)
# Requirement already satisfied: pyOpenSSL>=0.14 in c:\users\smjin\anaconda3\envs\ai\lib\site-packages (from urllib3[secure,socks]~=1.26->selenium==4.2.0) (23.0.0)
# Requirement already satisfied: urllib3-secure-extra in c:\users\smjin\anaconda3\envs\ai\lib\site-packages (from urllib3[secure,socks]~=1.26->selenium==4.2.0) (0.1.0)
# Requirement already satisfied: certifi in c:\users\smjin\anaconda3\envs\ai\lib\site-packages (from urllib3[secure,socks]~=1.26->selenium==4.2.0) (2023.5.7)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\smjin\anaconda3\envs\ai\lib\site-packages (from urllib3[secure,socks]~=1.26->selenium==4.2.0) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\smjin\anaconda3\envs\ai\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium==4.2.0) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\smjin\anaconda3\envs\ai\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium==4.2.0) (0.14.0)

# %%
import selenium

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service

import time
import os
import urllib, requests

# %%
# 1. query, chromedriver 실행
query = '사과'
service = Service("./chromedriver")
driver = webdriver.Chrome(service=service)
driver.implicitly_wait(3)

# query 검색창에 추가
driver.get("https://www.google.co.kr/imghp?h1=ko")
keyword = driver.find_element_by_xpath("/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/textarea")
keyword.send_keys(query)
# /html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/textarea   -> 검색창
# /html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/button   -> 검색창 버튼


# 검색창에 입력이 들어오면 검색 실행
# test = driver.find_element_by_xpath("/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/button").click()
driver.find_element_by_class_name('Tg7LZd').send_keys(Keys.ENTER)
# test.click()

# driver.implicitly_wait(3)

elem = driver.find_element_by_tag_name('body')
for i in range(60):
    elem.send_keys(Keys.PAGE_DOWN)
    time.sleep(0.1)
    
try :
    driver.find_element_by_class_name("mye4qd").send_keys(Keys.ENTER)
    for i in range(60):
        elem.send_keys(Keys.PAGE_DOWN)
        time.sleep(0.1)
except:
    pass

# 5. 이미지 개수 파악하기
links = []
images = driver.find_elements_by_css_selector("img.rg_i")


for image in images:
    if image.get_attribute('data-src') != None:
        links.append(image.get_attribute('data-src'))
    elif image.get_attribute('data-iurl') != None:
        links.append(image.get_attribute('data-iurl'))
    elif image.get_attribute('src') != None:
        links.append(image.get_attribute('src'))
        
print('찾은 이미지 개수 : ', len(links))

### 6. 이미지 다운로드
count = 0
for i in links:
    start = time.time()
    url = i
#     webdriver.ActionChains(driver).click(i).perform()
#     imgurl = driver.find_element_by_xpath('')
    os.makedirs("./download_image_data", exist_ok = True)
    while True :
        try :
            urllib.request.urlretrieve(url, f"./download_image_data/{str(count)}_apple.png")
            print(f"{str(count + 1)} / {str(len(links))} / {query} / 다운로드 시간 : {str(time.time() - start)[:5]} 초")
            break
        except urllib.error.HTTPError as e :
            print(f"HTTPError 발생 ({e}): 재시도 중 .......")
            time.sleep(5)
        except Exception as e:
            print(f"Error 발생 ({e}) : 재시도 중 ........")
            time.sleep(5)
        if time.time() - start > 60 :
            print("이미지 다운로드 실패 ...")
            break
    count = count + 1
                      
print("다운로드 완료")
driver.close()
# Out:
# C:\Users\smjin\AppData\Local\Temp\ipykernel_16804\4164696355.py:9: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   keyword = driver.find_element_by_xpath("/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/textarea")
# C:\Users\smjin\AppData\Local\Temp\ipykernel_16804\4164696355.py:17: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   driver.find_element_by_class_name('Tg7LZd').send_keys(Keys.ENTER)
# C:\Users\smjin\AppData\Local\Temp\ipykernel_16804\4164696355.py:22: DeprecationWarning: find_element_by_tag_name is deprecated. Please use find_element(by=By.TAG_NAME, value=name) instead
#   elem = driver.find_element_by_tag_name('body')
# C:\Users\smjin\AppData\Local\Temp\ipykernel_16804\4164696355.py:28: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   driver.find_element_by_class_name("mye4qd").send_keys(Keys.ENTER)
# C:\Users\smjin\AppData\Local\Temp\ipykernel_16804\4164696355.py:37: DeprecationWarning: find_elements_by_css_selector is deprecated. Please use find_elements(by=By.CSS_SELECTOR, value=css_selector) instead
#   images = driver.find_elements_by_css_selector("img.rg_i")
# 찾은 이미지 개수 :  200
# 1 / 200 / 사과 / 다운로드 시간 : 0.000 초
# 2 / 200 / 사과 / 다운로드 시간 : 0.001 초
# 3 / 200 / 사과 / 다운로드 시간 : 0.001 초
# 4 / 200 / 사과 / 다운로드 시간 : 0.001 초
# 5 / 200 / 사과 / 다운로드 시간 : 0.000 초
# 6 / 200 / 사과 / 다운로드 시간 : 0.001 초
# 7 / 200 / 사과 / 다운로드 시간 : 0.0 초
# 8 / 200 / 사과 / 다운로드 시간 : 0.000 초
# 9 / 200 / 사과 / 다운로드 시간 : 0.001 초
# 10 / 200 / 사과 / 다운로드 시간 : 0.001 초
# 11 / 200 / 사과 / 다운로드 시간 : 0.001 초
# 12 / 200 / 사과 / 다운로드 시간 : 0.001 초
# 13 / 200 / 사과 / 다운로드 시간 : 0.000 초
# 14 / 200 / 사과 / 다운로드 시간 : 0.001 초
# 15 / 200 / 사과 / 다운로드 시간 : 0.001 초
# 16 / 200 / 사과 / 다운로드 시간 : 0.000 초
# 17 / 200 / 사과 / 다운로드 시간 : 0.202 초
# 18 / 200 / 사과 / 다운로드 시간 : 0.180 초
# 19 / 200 / 사과 / 다운로드 시간 : 0.161 초
# 20 / 200 / 사과 / 다운로드 시간 : 0.174 초
# 21 / 200 / 사과 / 다운로드 시간 : 0.167 초
# 22 / 200 / 사과 / 다운로드 시간 : 0.220 초
# 23 / 200 / 사과 / 다운로드 시간 : 0.178 초
# 24 / 200 / 사과 / 다운로드 시간 : 0.179 초
# 25 / 200 / 사과 / 다운로드 시간 : 0.154 초
# 26 / 200 / 사과 / 다운로드 시간 : 0.181 초
# 27 / 200 / 사과 / 다운로드 시간 : 0.179 초
# 28 / 200 / 사과 / 다운로드 시간 : 0.173 초
# 29 / 200 / 사과 / 다운로드 시간 : 0.173 초
# 168 / 200 / 사과 / 다운로드 시간 : 0.175 초
# 169 / 200 / 사과 / 다운로드 시간 : 0.177 초
# 170 / 200 / 사과 / 다운로드 시간 : 0.165 초
# 171 / 200 / 사과 / 다운로드 시간 : 0.161 초
# 172 / 200 / 사과 / 다운로드 시간 : 0.187 초
# 173 / 200 / 사과 / 다운로드 시간 : 0.177 초
# 174 / 200 / 사과 / 다운로드 시간 : 0.179 초
# 175 / 200 / 사과 / 다운로드 시간 : 0.168 초
# 176 / 200 / 사과 / 다운로드 시간 : 0.181 초
# 177 / 200 / 사과 / 다운로드 시간 : 0.159 초
# 178 / 200 / 사과 / 다운로드 시간 : 0.160 초
# 179 / 200 / 사과 / 다운로드 시간 : 0.187 초
# 180 / 200 / 사과 / 다운로드 시간 : 0.164 초
# 181 / 200 / 사과 / 다운로드 시간 : 0.171 초
# 182 / 200 / 사과 / 다운로드 시간 : 0.170 초
# 183 / 200 / 사과 / 다운로드 시간 : 0.175 초
# 184 / 200 / 사과 / 다운로드 시간 : 0.191 초
# 185 / 200 / 사과 / 다운로드 시간 : 0.163 초
# 186 / 200 / 사과 / 다운로드 시간 : 0.180 초
# 187 / 200 / 사과 / 다운로드 시간 : 0.169 초
# 188 / 200 / 사과 / 다운로드 시간 : 0.179 초
# 189 / 200 / 사과 / 다운로드 시간 : 0.158 초
# 190 / 200 / 사과 / 다운로드 시간 : 0.167 초
# 191 / 200 / 사과 / 다운로드 시간 : 0.177 초
# 192 / 200 / 사과 / 다운로드 시간 : 0.166 초
# 193 / 200 / 사과 / 다운로드 시간 : 0.183 초
# 194 / 200 / 사과 / 다운로드 시간 : 0.163 초
# 195 / 200 / 사과 / 다운로드 시간 : 0.174 초
# 196 / 200 / 사과 / 다운로드 시간 : 0.164 초
# 197 / 200 / 사과 / 다운로드 시간 : 0.173 초
# 198 / 200 / 사과 / 다운로드 시간 : 0.183 초
# 199 / 200 / 사과 / 다운로드 시간 : 0.178 초
# 200 / 200 / 사과 / 다운로드 시간 : 0.188 초
# 다운로드 완료

# %%
# !pip install natsort
# Out:
# Collecting natsort
#   Downloading natsort-8.3.1-py3-none-any.whl (38 kB)
# Installing collected packages: natsort
# Successfully installed natsort-8.3.1

# %%
# os listdir
import os
img_dir = './download_image_data'

file_list = os.listdir(img_dir)
print(file_list)
# Out:
# ['0_apple.png', '100_apple.png', '101_apple.png', '102_apple.png', '103_apple.png', '104_apple.png', '105_apple.png', '106_apple.png', '107_apple.png', '108_apple.png', '109_apple.png', '10_apple.png', '110_apple.png', '111_apple.png', '112_apple.png', '113_apple.png', '114_apple.png', '115_apple.png', '116_apple.png', '117_apple.png', '118_apple.png', '119_apple.png', '11_apple.png', '120_apple.png', '121_apple.png', '122_apple.png', '123_apple.png', '124_apple.png', '125_apple.png', '126_apple.png', '127_apple.png', '128_apple.png', '129_apple.png', '12_apple.png', '130_apple.png', '131_apple.png', '132_apple.png', '133_apple.png', '134_apple.png', '135_apple.png', '136_apple.png', '137_apple.png', '138_apple.png', '139_apple.png', '13_apple.png', '140_apple.png', '141_apple.png', '142_apple.png', '143_apple.png', '144_apple.png', '145_apple.png', '146_apple.png', '147_apple.png', '148_apple.png', '149_apple.png', '14_apple.png', '150_apple.png', '151_apple.png', '152_apple.png', '153_apple.png', '154_apple.png', '155_apple.png', '156_apple.png', '157_apple.png', '158_apple.png', '159_apple.png', '15_apple.png', '160_apple.png', '161_apple.png', '162_apple.png', '163_apple.png', '164_apple.png', '165_apple.png', '166_apple.png', '167_apple.png', '168_apple.png', '169_apple.png', '16_apple.png', '170_apple.png', '171_apple.png', '172_apple.png', '173_apple.png', '174_apple.png', '175_apple.png', '176_apple.png', '177_apple.png', '178_apple.png', '179_apple.png', '17_apple.png', '180_apple.png', '181_apple.png', '182_apple.png', '183_apple.png', '184_apple.png', '185_apple.png', '186_apple.png', '187_apple.png', '188_apple.png', '189_apple.png', '18_apple.png', '190_apple.png', '191_apple.png', '192_apple.png', '193_apple.png', '194_apple.png', '195_apple.png', '196_apple.png', '197_apple.png', '198_apple.png', '199_apple.png', '19_apple.png', '1_apple.png', '20_apple.png', '21_apple.png', '22_apple.png', '23_apple.png', '24_apple.png', '25_apple.png', '26_apple.png', '27_apple.png', '28_apple.png', '29_apple.png', '2_apple.png', '30_apple.png', '31_apple.png', '32_apple.png', '33_apple.png', '34_apple.png', '35_apple.png', '36_apple.png', '37_apple.png', '38_apple.png', '39_apple.png', '3_apple.png', '40_apple.png', '41_apple.png', '42_apple.png', '43_apple.png', '44_apple.png', '45_apple.png', '46_apple.png', '47_apple.png', '48_apple.png', '49_apple.png', '4_apple.png', '50_apple.png', '51_apple.png', '52_apple.png', '53_apple.png', '54_apple.png', '55_apple.png', '56_apple.png', '57_apple.png', '58_apple.png', '59_apple.png', '5_apple.png', '60_apple.png', '61_apple.png', '62_apple.png', '63_apple.png', '64_apple.png', '65_apple.png', '66_apple.png', '67_apple.png', '68_apple.png', '69_apple.png', '6_apple.png', '70_apple.png', '71_apple.png', '72_apple.png', '73_apple.png', '74_apple.png', '75_apple.png', '76_apple.png', '77_apple.png', '78_apple.png', '79_apple.png', '7_apple.png', '80_apple.png', '81_apple.png', '82_apple.png', '83_apple.png', '84_apple.png', '85_apple.png', '86_apple.png', '87_apple.png', '88_apple.png', '89_apple.png', '8_apple.png', '90_apple.png', '91_apple.png', '92_apple.png', '93_apple.png', '94_apple.png', '95_apple.png', '96_apple.png', '97_apple.png', '98_apple.png', '99_apple.png', '9_apple.png']

# %%
from natsort import natsort
import glob

file_list_sort = natsort.natsorted(glob.glob(os.path.join("./apple/", "*.png")))
print(file_list_sort)
# Out:
# []
